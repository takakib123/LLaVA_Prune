# %%
# !git clone https://github.com/takakib123/LLaVA_Prune.git
# Out:
# Cloning into 'LLaVA_Prune'...
# remote: Enumerating objects: 164, done.
# remote: Counting objects: 100% (164/164), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 164 (delta 85), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (164/164), 182.75 KiB | 8.31 MiB/s, done.
# Resolving deltas: 100% (85/85), done.

# %%
# %cd /kaggle/working/LLaVA_Prune
# Out:
# /kaggle/working/LLaVA_Prune

# %%
# !pip install -e .
# Out:
# Obtaining file:///kaggle/working/LLaVA_Prune
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for llava-prune
# ...

# %%
# !llava-pruning --model-name "Aranya31/Derm-LLaVA-1.5-7b-conv2" \
              --unimportance-orders "23,4,18" \
              --output-dir "./pruned_models"
# Out:
# 2025-03-18 16:21:04.394969: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-03-18 16:21:04.416550: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-03-18 16:21:04.424054: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Pruning model Aranya31/Derm-LLaVA-1.5-7b-conv2 with unimportance orders: [23, 4, 18]
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:00<00:00,  3.59it/s]
# # blocks before pruning: 32
#  ** excluded blocks [23, 4, 18]
# copy time --- 56.2 sec
# Saving pruned model to ./pruned_models/Derm-LLaVA-1.5-7b-conv2_pruned_layers_23_4_18
# ...
